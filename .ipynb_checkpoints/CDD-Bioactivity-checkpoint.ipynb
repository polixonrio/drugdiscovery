# %% [markdown]
# <h1>Bioinformatics Project - Computational Drug Discovery</h1>

# %% [markdown]
# ChEMBL Database
# The ChEMBL Database is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 84,000 documents, 1.2 million assays and the data spans 14,855 targets and 1,800 cells and 33,000 indications. [Data as of March 25, 2020; ChEMBL version 26].

# %%
# !pip install chembl_webresource_client
# Out:
# Requirement already satisfied: chembl_webresource_client in c:\users\lyrian\anaconda3\lib\site-packages (0.10.8)
# Requirement already satisfied: requests>=2.18.4 in c:\users\lyrian\anaconda3\lib\site-packages (from chembl_webresource_client) (2.27.1)
# Requirement already satisfied: easydict in c:\users\lyrian\anaconda3\lib\site-packages (from chembl_webresource_client) (1.9)
# Requirement already satisfied: urllib3 in c:\users\lyrian\anaconda3\lib\site-packages (from chembl_webresource_client) (1.26.9)
# Requirement already satisfied: requests-cache~=0.7.0 in c:\users\lyrian\anaconda3\lib\site-packages (from chembl_webresource_client) (0.7.5)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lyrian\anaconda3\lib\site-packages (from requests>=2.18.4->chembl_webresource_client) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lyrian\anaconda3\lib\site-packages (from requests>=2.18.4->chembl_webresource_client) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\lyrian\anaconda3\lib\site-packages (from requests>=2.18.4->chembl_webresource_client) (2.0.4)
# Requirement already satisfied: attrs<22.0,>=21.2 in c:\users\lyrian\anaconda3\lib\site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (21.4.0)
# Requirement already satisfied: url-normalize<2.0,>=1.4 in c:\users\lyrian\anaconda3\lib\site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (1.4.3)
# Requirement already satisfied: itsdangerous>=2.0.1 in c:\users\lyrian\anaconda3\lib\site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (2.0.1)
# Requirement already satisfied: pyyaml>=5.4 in c:\users\lyrian\anaconda3\lib\site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (6.0)
# Requirement already satisfied: six in c:\users\lyrian\anaconda3\lib\site-packages (from url-normalize<2.0,>=1.4->requests-cache~=0.7.0->chembl_webresource_client) (1.16.0)

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('coronavirus')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [{'xref_id': 'P0C6U8', 'xref_name': None, 'xre...
# 5                                                 []
# 6  [{'xref_id': 'P0C6X7', 'xref_name': None, 'xre...
# 7                                                 []
#
#                                             organism  \
# 0                                        Coronavirus
# 1                                   SARS coronavirus
# 2                                 Feline coronavirus
# 3                             Human coronavirus 229E
# 4                                   SARS coronavirus
# 5  Middle East respiratory syndrome-related coron...
# 6                                   SARS coronavirus
# 7    Severe acute respiratory syndrome coronavirus 2
#
#                                            pref_name  score  \
# 0                                        Coronavirus   17.0
# 1                                   SARS coronavirus   15.0
# 2                                 Feline coronavirus   15.0
# 3                             Human coronavirus 229E   13.0
# 4                SARS coronavirus 3C-like proteinase   10.0
# 5  Middle East respiratory syndrome-related coron...    9.0
# 6                          Replicase polyprotein 1ab    4.0
# 7                          Replicase polyprotein 1ab    4.0
#
#    species_group_flag target_chembl_id  \
# 0               False     CHEMBL613732
# 1               False     CHEMBL612575
# 2               False     CHEMBL612744
# 3               False     CHEMBL613837
# 4               False       CHEMBL3927
# 5               False    CHEMBL4296578
# 6               False       CHEMBL5118
# 7               False    CHEMBL4523582
#
#                                    target_components     target_type   tax_id
# 0                                                 []        ORGANISM    11119
# 1                                                 []        ORGANISM   227859
# 2                                                 []        ORGANISM    12663
# 3                                                 []        ORGANISM    11137
# 4  [{'accession': 'P0C6U8', 'component_descriptio...  SINGLE PROTEIN   227859
# 5                                                 []        ORGANISM  1335626
# 6  [{'accession': 'P0C6X7', 'component_descriptio...  SINGLE PROTEIN   227859
# 7  [{'accession': 'P0DTD1', 'component_descriptio...  SINGLE PROTEIN  2697049

# %% [markdown]
# Select and retreive bioactivity data for Severe acute respiratory syndrome coronavirus 2 {EIGHTH ENTRY}

# %%
selected_target = targets.target_chembl_id[7]
selected_target
# Out:
# 'CHEMBL4523582'

# %% [markdown]
# We will retreive bioactivity data for Severe acute respiratory syndrome coronavirus 2 (CHEMBL4523582) that are reported as IC50 values in nM
#
# What is IC50 -via wikipedia
# The half maximal inhibitory concentration (IC50) is a measure of the potency of a substance in inhibiting a specific biological or biochemical function. IC50 is a quantitative measure that indicates how much of a particular inhibitory substance (e.g. drug) is needed to inhibit, in vitro, a given biological process or biological component by 50%. The biological component could be an enzyme, cell, cell receptor or microorganism. IC50 values are typically expressed as molar concentration.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id = selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
pd.set_option('display.max_columns', None)
df
# Out:
#     activity_comment  activity_id activity_properties assay_chembl_id  \
# 0    Dtt Insensitive     19964199                  []   CHEMBL4495583
# 1    Dtt Insensitive     19964200                  []   CHEMBL4495583
# 2    Dtt Insensitive     19964201                  []   CHEMBL4495583
# 3    Dtt Insensitive     19964202                  []   CHEMBL4495583
# 4    Dtt Insensitive     19964203                  []   CHEMBL4495583
# ..               ...          ...                 ...             ...
# 112  Dtt Insensitive     19964311                  []   CHEMBL4495583
# 113  Dtt Insensitive     19964312                  []   CHEMBL4495583
# 114  Dtt Insensitive     19964313                  []   CHEMBL4495583
# 115  Dtt Insensitive     19964314                  []   CHEMBL4495583
# 116  Dtt Insensitive     19964315                  []   CHEMBL4495583
#
#                                      assay_description assay_type  \
# 0    SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 1    SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 2    SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 3    SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 4    SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# ..                                                 ...        ...
# 112  SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 113  SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 114  SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 115  SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 116  SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
#
#     assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                      None                   None  BAO_0000190  BAO_0000019
# 1                      None                   None  BAO_0000190  BAO_0000019
# 2                      None                   None  BAO_0000190  BAO_0000019
# 3                      None                   None  BAO_0000190  BAO_0000019
# 4                      None                   None  BAO_0000190  BAO_0000019
# ..                      ...                    ...          ...          ...
# 112                    None                   None  BAO_0000190  BAO_0000019
# 113                    None                   None  BAO_0000190  BAO_0000019
# 114                    None                   None  BAO_0000190  BAO_0000019
# 115                    None                   None  BAO_0000190  BAO_0000019
# 116                    None                   None  BAO_0000190  BAO_0000019
#
#         bao_label                                   canonical_smiles  \
# 0    assay format   Cc1c(OCC(F)(F)F)ccnc1C[S+]([O-])c1nc2ccccc2[nH]1
# 1    assay format                              Cc1c(-c2cnccn2)ssc1=S
# 2    assay format            O=c1sn(-c2cccc3ccccc23)c(=O)n1Cc1ccccc1
# 3    assay format  O=C(O[C@@H]1Cc2c(O)cc(O)cc2O[C@@H]1c1cc(O)c(O)...
# 4    assay format                            O=C1C=Cc2cc(Br)ccc2C1=O
# ..            ...                                                ...
# 112  assay format                             C=CC(=O)c1ccc2ccccc2c1
# 113  assay format               C[n+]1c2cc(N)ccc2cc2ccc(N)cc21.[Cl-]
# 114  assay format             Nc1ccc(S(=O)(=O)[N-]c2ncccn2)cc1.[Ag+]
# 115  assay format                                               None
# 116  assay format  C[n+]1c2cc(N)ccc2cc2ccc(N)cc21.Cl.Nc1ccc2cc3cc...
#
#     data_validity_comment data_validity_description document_chembl_id  \
# 0                    None                      None      CHEMBL4495564
# 1                    None                      None      CHEMBL4495564
# 2                    None                      None      CHEMBL4495564
# 3                    None                      None      CHEMBL4495564
# 4                    None                      None      CHEMBL4495564
# ..                    ...                       ...                ...
# 112                  None                      None      CHEMBL4495564
# 113                  None                      None      CHEMBL4495564
# 114                  None                      None      CHEMBL4495564
# 115                  None                      None      CHEMBL4495564
# 116                  None                      None      CHEMBL4495564
#
#     document_journal  document_year ligand_efficiency molecule_chembl_id  \
# 0               None           2020              None          CHEMBL480
# 1               None           2020              None       CHEMBL178459
# 2               None           2020              None      CHEMBL3545157
# 3               None           2020              None       CHEMBL297453
# 4               None           2020              None      CHEMBL4303595
# ..               ...            ...               ...                ...
# 112             None           2020              None       CHEMBL154580
# 113             None           2020              None       CHEMBL354349
# 114             None           2020              None      CHEMBL1382627
# 115             None           2020              None      CHEMBL4303664
# 116             None           2020              None      CHEMBL1977761
#
#             molecule_pref_name parent_molecule_chembl_id pchembl_value  \
# 0                 LANSOPRAZOLE                 CHEMBL480          6.41
# 1                     OLTIPRAZ              CHEMBL178459          6.68
# 2                   TIDEGLUSIB             CHEMBL3545157          7.10
# 3      EPIGALOCATECHIN GALLATE              CHEMBL297453          5.80
# 4                         None             CHEMBL4303595          7.40
# ..                         ...                       ...           ...
# 112                       None              CHEMBL154580          5.91
# 113                  EUFLAVINE             CHEMBL1184529          5.30
# 114       SULFADIAZINE, SILVER                 CHEMBL439          6.12
# 115                       None             CHEMBL4303664          6.06
# 116  ACRIFLAVINE HYDROCHLORIDE             CHEMBL2010412          5.71
#
#      potential_duplicate                                 qudt_units  \
# 0                      0  http://www.openphacts.org/units/Nanomolar
# 1                      0  http://www.openphacts.org/units/Nanomolar
# 2                      0  http://www.openphacts.org/units/Nanomolar
# 3                      0  http://www.openphacts.org/units/Nanomolar
# 4                      0  http://www.openphacts.org/units/Nanomolar
# ..                   ...                                        ...
# 112                    0  http://www.openphacts.org/units/Nanomolar
# 113                    0  http://www.openphacts.org/units/Nanomolar
# 114                    0  http://www.openphacts.org/units/Nanomolar
# 115                    0  http://www.openphacts.org/units/Nanomolar
# 116                    0  http://www.openphacts.org/units/Nanomolar
#
#      record_id relation  src_id  standard_flag standard_relation  \
# 0      3341963        =      52              1                 =
# 1      3341991        =      52              1                 =
# 2      3342067        =      52              1                 =
# 3      3342156        =      52              1                 =
# 4      3342307        =      52              1                 =
# ..         ...      ...     ...            ...               ...
# 112    3350392        =      52              1                 =
# 113    3350497        =      52              1                 =
# 114    3350585        =      52              1                 =
# 115    3350604        =      52              1                 =
# 116    3350610        =      52              1                 =
#
#     standard_text_value standard_type standard_units standard_upper_value  \
# 0                  None          IC50             nM                 None
# 1                  None          IC50             nM                 None
# 2                  None          IC50             nM                 None
# 3                  None          IC50             nM                 None
# 4                  None          IC50             nM                 None
# ..                  ...           ...            ...                  ...
# 112                None          IC50             nM                 None
# 113                None          IC50             nM                 None
# 114                None          IC50             nM                 None
# 115                None          IC50             nM                 None
# 116                None          IC50             nM                 None
#
#     standard_value target_chembl_id  \
# 0            390.0    CHEMBL4523582
# 1            210.0    CHEMBL4523582
# 2             80.0    CHEMBL4523582
# 3           1580.0    CHEMBL4523582
# 4             40.0    CHEMBL4523582
# ..             ...              ...
# 112         1240.0    CHEMBL4523582
# 113         4980.0    CHEMBL4523582
# 114          750.0    CHEMBL4523582
# 115          880.0    CHEMBL4523582
# 116         1930.0    CHEMBL4523582
#
#                                      target_organism  \
# 0    Severe acute respiratory syndrome coronavirus 2
# 1    Severe acute respiratory syndrome coronavirus 2
# 2    Severe acute respiratory syndrome coronavirus 2
# 3    Severe acute respiratory syndrome coronavirus 2
# 4    Severe acute respiratory syndrome coronavirus 2
# ..                                               ...
# 112  Severe acute respiratory syndrome coronavirus 2
# 113  Severe acute respiratory syndrome coronavirus 2
# 114  Severe acute respiratory syndrome coronavirus 2
# 115  Severe acute respiratory syndrome coronavirus 2
# 116  Severe acute respiratory syndrome coronavirus 2
#
#               target_pref_name target_tax_id text_value  toid  type units  \
# 0    Replicase polyprotein 1ab       2697049       None  None  IC50    uM
# 1    Replicase polyprotein 1ab       2697049       None  None  IC50    uM
# 2    Replicase polyprotein 1ab       2697049       None  None  IC50    uM
# 3    Replicase polyprotein 1ab       2697049       None  None  IC50    uM
# 4    Replicase polyprotein 1ab       2697049       None  None  IC50    uM
# ..                         ...           ...        ...   ...   ...   ...
# 112  Replicase polyprotein 1ab       2697049       None  None  IC50    uM
# 113  Replicase polyprotein 1ab       2697049       None  None  IC50    uM
# 114  Replicase polyprotein 1ab       2697049       None  None  IC50    uM
# 115  Replicase polyprotein 1ab       2697049       None  None  IC50    uM
# 116  Replicase polyprotein 1ab       2697049       None  None  IC50    uM
#
#        uo_units upper_value value
# 0    UO_0000065        None  0.39
# 1    UO_0000065        None  0.21
# 2    UO_0000065        None  0.08
# 3    UO_0000065        None  1.58
# 4    UO_0000065        None  0.04
# ..          ...         ...   ...
# 112  UO_0000065        None  1.24
# 113  UO_0000065        None  4.98
# 114  UO_0000065        None  0.75
# 115  UO_0000065        None  0.88
# 116  UO_0000065        None  1.93
#
# [117 rows x 45 columns]

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# We will save the resulting bioactivity data to a CSV file

# %%
df.to_csv('bioactivity_data.csv', index=False)

# %% [markdown]
# <h2>Handling missing data</h2>
# If any compounds has missing value for the standard_value column then we drop it.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
#     activity_comment  activity_id activity_properties assay_chembl_id  \
# 0    Dtt Insensitive     19964199                  []   CHEMBL4495583
# 1    Dtt Insensitive     19964200                  []   CHEMBL4495583
# 2    Dtt Insensitive     19964201                  []   CHEMBL4495583
# 3    Dtt Insensitive     19964202                  []   CHEMBL4495583
# 4    Dtt Insensitive     19964203                  []   CHEMBL4495583
# ..               ...          ...                 ...             ...
# 111  Dtt Insensitive     19964310                  []   CHEMBL4495583
# 112  Dtt Insensitive     19964311                  []   CHEMBL4495583
# 113  Dtt Insensitive     19964312                  []   CHEMBL4495583
# 114  Dtt Insensitive     19964313                  []   CHEMBL4495583
# 116  Dtt Insensitive     19964315                  []   CHEMBL4495583
#
#                                      assay_description assay_type  \
# 0    SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 1    SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 2    SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 3    SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 4    SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# ..                                                 ...        ...
# 111  SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 112  SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 113  SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 114  SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 116  SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
#
#     assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                      None                   None  BAO_0000190  BAO_0000019
# 1                      None                   None  BAO_0000190  BAO_0000019
# 2                      None                   None  BAO_0000190  BAO_0000019
# 3                      None                   None  BAO_0000190  BAO_0000019
# 4                      None                   None  BAO_0000190  BAO_0000019
# ..                      ...                    ...          ...          ...
# 111                    None                   None  BAO_0000190  BAO_0000019
# 112                    None                   None  BAO_0000190  BAO_0000019
# 113                    None                   None  BAO_0000190  BAO_0000019
# 114                    None                   None  BAO_0000190  BAO_0000019
# 116                    None                   None  BAO_0000190  BAO_0000019
#
#         bao_label                                   canonical_smiles  \
# 0    assay format   Cc1c(OCC(F)(F)F)ccnc1C[S+]([O-])c1nc2ccccc2[nH]1
# 1    assay format                              Cc1c(-c2cnccn2)ssc1=S
# 2    assay format            O=c1sn(-c2cccc3ccccc23)c(=O)n1Cc1ccccc1
# 3    assay format  O=C(O[C@@H]1Cc2c(O)cc(O)cc2O[C@@H]1c1cc(O)c(O)...
# 4    assay format                            O=C1C=Cc2cc(Br)ccc2C1=O
# ..            ...                                                ...
# 111  assay format  COc1nc2ccc(Br)cc2cc1[C@@H](c1ccccc1)[C@@](O)(C...
# 112  assay format                             C=CC(=O)c1ccc2ccccc2c1
# 113  assay format               C[n+]1c2cc(N)ccc2cc2ccc(N)cc21.[Cl-]
# 114  assay format             Nc1ccc(S(=O)(=O)[N-]c2ncccn2)cc1.[Ag+]
# 116  assay format  C[n+]1c2cc(N)ccc2cc2ccc(N)cc21.Cl.Nc1ccc2cc3cc...
#
#     data_validity_comment data_validity_description document_chembl_id  \
# 0                    None                      None      CHEMBL4495564
# 1                    None                      None      CHEMBL4495564
# 2                    None                      None      CHEMBL4495564
# 3                    None                      None      CHEMBL4495564
# 4                    None                      None      CHEMBL4495564
# ..                    ...                       ...                ...
# 111                  None                      None      CHEMBL4495564
# 112                  None                      None      CHEMBL4495564
# 113                  None                      None      CHEMBL4495564
# 114                  None                      None      CHEMBL4495564
# 116                  None                      None      CHEMBL4495564
#
#     document_journal  document_year ligand_efficiency molecule_chembl_id  \
# 0               None           2020              None          CHEMBL480
# 1               None           2020              None       CHEMBL178459
# 2               None           2020              None      CHEMBL3545157
# 3               None           2020              None       CHEMBL297453
# 4               None           2020              None      CHEMBL4303595
# ..               ...            ...               ...                ...
# 111             None           2020              None       CHEMBL376488
# 112             None           2020              None       CHEMBL154580
# 113             None           2020              None       CHEMBL354349
# 114             None           2020              None      CHEMBL1382627
# 116             None           2020              None      CHEMBL1977761
#
#             molecule_pref_name parent_molecule_chembl_id pchembl_value  \
# 0                 LANSOPRAZOLE                 CHEMBL480          6.41
# 1                     OLTIPRAZ              CHEMBL178459          6.68
# 2                   TIDEGLUSIB             CHEMBL3545157          7.10
# 3      EPIGALOCATECHIN GALLATE              CHEMBL297453          5.80
# 4                         None             CHEMBL4303595          7.40
# ..                         ...                       ...           ...
# 111                BEDAQUILINE              CHEMBL376488          5.36
# 112                       None              CHEMBL154580          5.91
# 113                  EUFLAVINE             CHEMBL1184529          5.30
# 114       SULFADIAZINE, SILVER                 CHEMBL439          6.12
# 116  ACRIFLAVINE HYDROCHLORIDE             CHEMBL2010412          5.71
#
#      potential_duplicate                                 qudt_units  \
# 0                      0  http://www.openphacts.org/units/Nanomolar
# 1                      0  http://www.openphacts.org/units/Nanomolar
# 2                      0  http://www.openphacts.org/units/Nanomolar
# 3                      0  http://www.openphacts.org/units/Nanomolar
# 4                      0  http://www.openphacts.org/units/Nanomolar
# ..                   ...                                        ...
# 111                    0  http://www.openphacts.org/units/Nanomolar
# 112                    0  http://www.openphacts.org/units/Nanomolar
# 113                    0  http://www.openphacts.org/units/Nanomolar
# 114                    0  http://www.openphacts.org/units/Nanomolar
# 116                    0  http://www.openphacts.org/units/Nanomolar
#
#      record_id relation  src_id  standard_flag standard_relation  \
# 0      3341963        =      52              1                 =
# 1      3341991        =      52              1                 =
# 2      3342067        =      52              1                 =
# 3      3342156        =      52              1                 =
# 4      3342307        =      52              1                 =
# ..         ...      ...     ...            ...               ...
# 111    3350188        =      52              1                 =
# 112    3350392        =      52              1                 =
# 113    3350497        =      52              1                 =
# 114    3350585        =      52              1                 =
# 116    3350610        =      52              1                 =
#
#     standard_text_value standard_type standard_units standard_upper_value  \
# 0                  None          IC50             nM                 None
# 1                  None          IC50             nM                 None
# 2                  None          IC50             nM                 None
# 3                  None          IC50             nM                 None
# 4                  None          IC50             nM                 None
# ..                  ...           ...            ...                  ...
# 111                None          IC50             nM                 None
# 112                None          IC50             nM                 None
# 113                None          IC50             nM                 None
# 114                None          IC50             nM                 None
# 116                None          IC50             nM                 None
#
#     standard_value target_chembl_id  \
# 0            390.0    CHEMBL4523582
# 1            210.0    CHEMBL4523582
# 2             80.0    CHEMBL4523582
# 3           1580.0    CHEMBL4523582
# 4             40.0    CHEMBL4523582
# ..             ...              ...
# 111         4360.0    CHEMBL4523582
# 112         1240.0    CHEMBL4523582
# 113         4980.0    CHEMBL4523582
# 114          750.0    CHEMBL4523582
# 116         1930.0    CHEMBL4523582
#
#                                      target_organism  \
# 0    Severe acute respiratory syndrome coronavirus 2
# 1    Severe acute respiratory syndrome coronavirus 2
# 2    Severe acute respiratory syndrome coronavirus 2
# 3    Severe acute respiratory syndrome coronavirus 2
# 4    Severe acute respiratory syndrome coronavirus 2
# ..                                               ...
# 111  Severe acute respiratory syndrome coronavirus 2
# 112  Severe acute respiratory syndrome coronavirus 2
# 113  Severe acute respiratory syndrome coronavirus 2
# 114  Severe acute respiratory syndrome coronavirus 2
# 116  Severe acute respiratory syndrome coronavirus 2
#
#               target_pref_name target_tax_id text_value  toid  type units  \
# 0    Replicase polyprotein 1ab       2697049       None  None  IC50    uM
# 1    Replicase polyprotein 1ab       2697049       None  None  IC50    uM
# 2    Replicase polyprotein 1ab       2697049       None  None  IC50    uM
# 3    Replicase polyprotein 1ab       2697049       None  None  IC50    uM
# 4    Replicase polyprotein 1ab       2697049       None  None  IC50    uM
# ..                         ...           ...        ...   ...   ...   ...
# 111  Replicase polyprotein 1ab       2697049       None  None  IC50    uM
# 112  Replicase polyprotein 1ab       2697049       None  None  IC50    uM
# 113  Replicase polyprotein 1ab       2697049       None  None  IC50    uM
# 114  Replicase polyprotein 1ab       2697049       None  None  IC50    uM
# 116  Replicase polyprotein 1ab       2697049       None  None  IC50    uM
#
#        uo_units upper_value value
# 0    UO_0000065        None  0.39
# 1    UO_0000065        None  0.21
# 2    UO_0000065        None  0.08
# 3    UO_0000065        None  1.58
# 4    UO_0000065        None  0.04
# ..          ...         ...   ...
# 111  UO_0000065        None  4.36
# 112  UO_0000065        None  1.24
# 113  UO_0000065        None  4.98
# 114  UO_0000065        None  0.75
# 116  UO_0000065        None  1.93
#
# [110 rows x 45 columns]

# %%
len(df2.canonical_smiles.unique())
# Out:
# 102

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#     activity_comment  activity_id activity_properties assay_chembl_id  \
# 0    Dtt Insensitive     19964199                  []   CHEMBL4495583
# 1    Dtt Insensitive     19964200                  []   CHEMBL4495583
# 2    Dtt Insensitive     19964201                  []   CHEMBL4495583
# 3    Dtt Insensitive     19964202                  []   CHEMBL4495583
# 4    Dtt Insensitive     19964203                  []   CHEMBL4495583
# ..               ...          ...                 ...             ...
# 111  Dtt Insensitive     19964310                  []   CHEMBL4495583
# 112  Dtt Insensitive     19964311                  []   CHEMBL4495583
# 113  Dtt Insensitive     19964312                  []   CHEMBL4495583
# 114  Dtt Insensitive     19964313                  []   CHEMBL4495583
# 116  Dtt Insensitive     19964315                  []   CHEMBL4495583
#
#                                      assay_description assay_type  \
# 0    SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 1    SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 2    SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 3    SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 4    SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# ..                                                 ...        ...
# 111  SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 112  SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 113  SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 114  SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 116  SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
#
#     assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                      None                   None  BAO_0000190  BAO_0000019
# 1                      None                   None  BAO_0000190  BAO_0000019
# 2                      None                   None  BAO_0000190  BAO_0000019
# 3                      None                   None  BAO_0000190  BAO_0000019
# 4                      None                   None  BAO_0000190  BAO_0000019
# ..                      ...                    ...          ...          ...
# 111                    None                   None  BAO_0000190  BAO_0000019
# 112                    None                   None  BAO_0000190  BAO_0000019
# 113                    None                   None  BAO_0000190  BAO_0000019
# 114                    None                   None  BAO_0000190  BAO_0000019
# 116                    None                   None  BAO_0000190  BAO_0000019
#
#         bao_label                                   canonical_smiles  \
# 0    assay format   Cc1c(OCC(F)(F)F)ccnc1C[S+]([O-])c1nc2ccccc2[nH]1
# 1    assay format                              Cc1c(-c2cnccn2)ssc1=S
# 2    assay format            O=c1sn(-c2cccc3ccccc23)c(=O)n1Cc1ccccc1
# 3    assay format  O=C(O[C@@H]1Cc2c(O)cc(O)cc2O[C@@H]1c1cc(O)c(O)...
# 4    assay format                            O=C1C=Cc2cc(Br)ccc2C1=O
# ..            ...                                                ...
# 111  assay format  COc1nc2ccc(Br)cc2cc1[C@@H](c1ccccc1)[C@@](O)(C...
# 112  assay format                             C=CC(=O)c1ccc2ccccc2c1
# 113  assay format               C[n+]1c2cc(N)ccc2cc2ccc(N)cc21.[Cl-]
# 114  assay format             Nc1ccc(S(=O)(=O)[N-]c2ncccn2)cc1.[Ag+]
# 116  assay format  C[n+]1c2cc(N)ccc2cc2ccc(N)cc21.Cl.Nc1ccc2cc3cc...
#
#     data_validity_comment data_validity_description document_chembl_id  \
# 0                    None                      None      CHEMBL4495564
# 1                    None                      None      CHEMBL4495564
# 2                    None                      None      CHEMBL4495564
# 3                    None                      None      CHEMBL4495564
# 4                    None                      None      CHEMBL4495564
# ..                    ...                       ...                ...
# 111                  None                      None      CHEMBL4495564
# 112                  None                      None      CHEMBL4495564
# 113                  None                      None      CHEMBL4495564
# 114                  None                      None      CHEMBL4495564
# 116                  None                      None      CHEMBL4495564
#
#     document_journal  document_year ligand_efficiency molecule_chembl_id  \
# 0               None           2020              None          CHEMBL480
# 1               None           2020              None       CHEMBL178459
# 2               None           2020              None      CHEMBL3545157
# 3               None           2020              None       CHEMBL297453
# 4               None           2020              None      CHEMBL4303595
# ..               ...            ...               ...                ...
# 111             None           2020              None       CHEMBL376488
# 112             None           2020              None       CHEMBL154580
# 113             None           2020              None       CHEMBL354349
# 114             None           2020              None      CHEMBL1382627
# 116             None           2020              None      CHEMBL1977761
#
#             molecule_pref_name parent_molecule_chembl_id pchembl_value  \
# 0                 LANSOPRAZOLE                 CHEMBL480          6.41
# 1                     OLTIPRAZ              CHEMBL178459          6.68
# 2                   TIDEGLUSIB             CHEMBL3545157          7.10
# 3      EPIGALOCATECHIN GALLATE              CHEMBL297453          5.80
# 4                         None             CHEMBL4303595          7.40
# ..                         ...                       ...           ...
# 111                BEDAQUILINE              CHEMBL376488          5.36
# 112                       None              CHEMBL154580          5.91
# 113                  EUFLAVINE             CHEMBL1184529          5.30
# 114       SULFADIAZINE, SILVER                 CHEMBL439          6.12
# 116  ACRIFLAVINE HYDROCHLORIDE             CHEMBL2010412          5.71
#
#      potential_duplicate                                 qudt_units  \
# 0                      0  http://www.openphacts.org/units/Nanomolar
# 1                      0  http://www.openphacts.org/units/Nanomolar
# 2                      0  http://www.openphacts.org/units/Nanomolar
# 3                      0  http://www.openphacts.org/units/Nanomolar
# 4                      0  http://www.openphacts.org/units/Nanomolar
# ..                   ...                                        ...
# 111                    0  http://www.openphacts.org/units/Nanomolar
# 112                    0  http://www.openphacts.org/units/Nanomolar
# 113                    0  http://www.openphacts.org/units/Nanomolar
# 114                    0  http://www.openphacts.org/units/Nanomolar
# 116                    0  http://www.openphacts.org/units/Nanomolar
#
#      record_id relation  src_id  standard_flag standard_relation  \
# 0      3341963        =      52              1                 =
# 1      3341991        =      52              1                 =
# 2      3342067        =      52              1                 =
# 3      3342156        =      52              1                 =
# 4      3342307        =      52              1                 =
# ..         ...      ...     ...            ...               ...
# 111    3350188        =      52              1                 =
# 112    3350392        =      52              1                 =
# 113    3350497        =      52              1                 =
# 114    3350585        =      52              1                 =
# 116    3350610        =      52              1                 =
#
#     standard_text_value standard_type standard_units standard_upper_value  \
# 0                  None          IC50             nM                 None
# 1                  None          IC50             nM                 None
# 2                  None          IC50             nM                 None
# 3                  None          IC50             nM                 None
# 4                  None          IC50             nM                 None
# ..                  ...           ...            ...                  ...
# 111                None          IC50             nM                 None
# 112                None          IC50             nM                 None
# 113                None          IC50             nM                 None
# 114                None          IC50             nM                 None
# 116                None          IC50             nM                 None
#
#     standard_value target_chembl_id  \
# 0            390.0    CHEMBL4523582
# 1            210.0    CHEMBL4523582
# 2             80.0    CHEMBL4523582
# 3           1580.0    CHEMBL4523582
# 4             40.0    CHEMBL4523582
# ..             ...              ...
# 111         4360.0    CHEMBL4523582
# 112         1240.0    CHEMBL4523582
# 113         4980.0    CHEMBL4523582
# 114          750.0    CHEMBL4523582
# 116         1930.0    CHEMBL4523582
#
#                                      target_organism  \
# 0    Severe acute respiratory syndrome coronavirus 2
# 1    Severe acute respiratory syndrome coronavirus 2
# 2    Severe acute respiratory syndrome coronavirus 2
# 3    Severe acute respiratory syndrome coronavirus 2
# 4    Severe acute respiratory syndrome coronavirus 2
# ..                                               ...
# 111  Severe acute respiratory syndrome coronavirus 2
# 112  Severe acute respiratory syndrome coronavirus 2
# 113  Severe acute respiratory syndrome coronavirus 2
# 114  Severe acute respiratory syndrome coronavirus 2
# 116  Severe acute respiratory syndrome coronavirus 2
#
#               target_pref_name target_tax_id text_value  toid  type units  \
# 0    Replicase polyprotein 1ab       2697049       None  None  IC50    uM
# 1    Replicase polyprotein 1ab       2697049       None  None  IC50    uM
# 2    Replicase polyprotein 1ab       2697049       None  None  IC50    uM
# 3    Replicase polyprotein 1ab       2697049       None  None  IC50    uM
# 4    Replicase polyprotein 1ab       2697049       None  None  IC50    uM
# ..                         ...           ...        ...   ...   ...   ...
# 111  Replicase polyprotein 1ab       2697049       None  None  IC50    uM
# 112  Replicase polyprotein 1ab       2697049       None  None  IC50    uM
# 113  Replicase polyprotein 1ab       2697049       None  None  IC50    uM
# 114  Replicase polyprotein 1ab       2697049       None  None  IC50    uM
# 116  Replicase polyprotein 1ab       2697049       None  None  IC50    uM
#
#        uo_units upper_value value
# 0    UO_0000065        None  0.39
# 1    UO_0000065        None  0.21
# 2    UO_0000065        None  0.08
# 3    UO_0000065        None  1.58
# 4    UO_0000065        None  0.04
# ..          ...         ...   ...
# 111  UO_0000065        None  4.36
# 112  UO_0000065        None  1.24
# 113  UO_0000065        None  4.98
# 114  UO_0000065        None  0.75
# 116  UO_0000065        None  1.93
#
# [102 rows x 45 columns]

# %% [markdown]
# <h2> Data pre-processing of the bioactivity data </h2>

# %% [markdown]
# Labelling compunds as either being active, inactive or intermediate
#
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be active while those greater than 10,000 nM will be considered to be inactive. As for those values in between 1,000 and 10,000, nM will be referred to as intermediate.

# %%
selection = ['molecule_chembl_id', 'canonical_smiles', 'standard_value']
df3 = df2_nr[selection]
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0            CHEMBL480   Cc1c(OCC(F)(F)F)ccnc1C[S+]([O-])c1nc2ccccc2[nH]1
# 1         CHEMBL178459                              Cc1c(-c2cnccn2)ssc1=S
# 2        CHEMBL3545157            O=c1sn(-c2cccc3ccccc23)c(=O)n1Cc1ccccc1
# 3         CHEMBL297453  O=C(O[C@@H]1Cc2c(O)cc(O)cc2O[C@@H]1c1cc(O)c(O)...
# 4        CHEMBL4303595                            O=C1C=Cc2cc(Br)ccc2C1=O
# ..                 ...                                                ...
# 111       CHEMBL376488  COc1nc2ccc(Br)cc2cc1[C@@H](c1ccccc1)[C@@](O)(C...
# 112       CHEMBL154580                             C=CC(=O)c1ccc2ccccc2c1
# 113       CHEMBL354349               C[n+]1c2cc(N)ccc2cc2ccc(N)cc21.[Cl-]
# 114      CHEMBL1382627             Nc1ccc(S(=O)(=O)[N-]c2ncccn2)cc1.[Ag+]
# 116      CHEMBL1977761  C[n+]1c2cc(N)ccc2cc2ccc(N)cc21.Cl.Nc1ccc2cc3cc...
#
#     standard_value
# 0            390.0
# 1            210.0
# 2             80.0
# 3           1580.0
# 4             40.0
# ..             ...
# 111         4360.0
# 112         1240.0
# 113         4980.0
# 114          750.0
# 116         1930.0
#
# [102 rows x 3 columns]

# %%
df4 = pd.read_csv(
